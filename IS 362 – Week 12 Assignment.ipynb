# %% [markdown]
# # IS 362 – Week 12 Assignment

# %% [markdown]
# ### Tasks:
# The New York Times web site provides a rich set of APIs, as described here: http://developer.nytimes.com/docs
# You’ll need to start by signing up for an API key.
# Your task is to choose one of the New York Times APIs, construct an interface in Python to read in the JSON data, and transform it into a pandas DataFrame.

# %% [markdown]
# ##### 1. Lets import pandas and JSON

# %%
import pandas as pd
import urllib.request
import json
from pandas.io.json import json_normalize

# %% [markdown]
# ##### 2. Read API data and display into the DataFrame

# %%
api_key = '49a4adf348c240648b14efdbecea6e4e'
url = 'https://api.nytimes.com/svc/books/v3/lists/best-sellers/history.json?'
string = url+'&api-key='+api_key

response = str(urllib.request.urlopen(string).read(), 'utf-8')

BestSeller = pd.read_json(response)
BestSeller
# Out:
#                                             copyright  num_results  \
# 0   Copyright (c) 2017 The New York Times Company....        30984
# 1   Copyright (c) 2017 The New York Times Company....        30984
# 2   Copyright (c) 2017 The New York Times Company....        30984
# 3   Copyright (c) 2017 The New York Times Company....        30984
# 4   Copyright (c) 2017 The New York Times Company....        30984
# 5   Copyright (c) 2017 The New York Times Company....        30984
# 6   Copyright (c) 2017 The New York Times Company....        30984
# 7   Copyright (c) 2017 The New York Times Company....        30984
# 8   Copyright (c) 2017 The New York Times Company....        30984
# 9   Copyright (c) 2017 The New York Times Company....        30984
# 10  Copyright (c) 2017 The New York Times Company....        30984
# 11  Copyright (c) 2017 The New York Times Company....        30984
# 12  Copyright (c) 2017 The New York Times Company....        30984
# ...

# %% [markdown]
# ##### 3. Lets display data into a DataFrame

# %%
DisplayData = json.loads(response)
BestSeller = json_normalize(DisplayData['results'])
BestSeller
# Out:
#    age_group                                 author  \
# 0                                    Diana Gabaldon
# 1              Annette Gordon-Reed and Peter S Onuf
# 2                                   Gary Vaynerchuk
# 3                                    Sophia Amoruso
# 4                                  Chris Guillebeau
# 5                               Christopher Steiner
# 6       None                           Steve Monroe
# 7       None  GEOFFREY STOKES, KEN TUCKER' 'ED WARD
# 8       None                         KATE TELTSCHER
# 9                                       Sharon Sala
# 10                                     Amanda Quick
# 11      None                   Naomi Schaefer Riley
# 12                                         Ron Carr
# 13               Action Bronson with Rachel Wharton
# 14      None                         James Carville
# 15                                 Hamazaki Tatsuya
# 16      None                   David Adams Richards
# ...
